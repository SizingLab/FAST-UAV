# %% [markdown]
# # FAST-UAV - Fixed-Wing Design Optimization + Higher fidelidity aerodynamics
# *Author: Félix Pollet - 2023* <br>
# *Co-author: Fernando Urquía Cutillas - 2026* <br>

# %% [markdown]
# This notebook provides an example of design optimization of a fixed-wing UAV. The process is the same as the one for multirotor UAVs, except that some models and variables are different (e.g., for defining the wing geometry).

# %% [markdown]
# ## 1. Setting up and analyzing the initial problem

# %%
# Import required librairies
import os.path as pth
import openmdao.api as om
import logging
import warnings
import shutil
import fastoad.api as oad
from time import time
import matplotlib.pyplot as plt
from fastuav.utils.postprocessing.analysis_and_plots import *

# Declare paths to folders and files
DATA_FOLDER_PATH = "./data"
WORK_FOLDER_PATH = "./workdir"
CONFIGURATION_FOLDER_PATH = pth.join(DATA_FOLDER_PATH, "configurations")
SOURCE_FOLDER_PATH = pth.join(DATA_FOLDER_PATH, "source_files")

CONFIGURATION_FILE = pth.join(CONFIGURATION_FOLDER_PATH, "fixedwing_mdo_NonPropu_Thin.yaml")

# SOURCE_FILE = pth.join(SOURCE_FOLDER_PATH, "problem_inputs_FW.xml")  # Source file provided for the example
SOURCE_FILE = pth.join(SOURCE_FOLDER_PATH, "problem_inputs_FMUC_NoPropu_Thin.xml")  # Source file provided for the example

# For having log messages display on screen
#logging.basicConfig(level=logging.INFO, format="%(levelname)-8s: %(message)s")
#warnings.filterwarnings(action="ignore")

# For using all screen width
from IPython.display import display, HTML, IFrame
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# As you can see in the following N2 diagram, some models used for the fixed-wing UAV are (obviously) different from the multirotor ones. Have a look at the geometry discipline. The arms and body frame have been replaced by wings, tails, and a fuselage. The aerodynamics module also includes models for estimating the parasitic drag, among others.

# %%
import html
import webbrowser
N2_FILE = pth.join(WORK_FOLDER_PATH, "n2_fixed-wing.html")

# Display the N2 file (works in VSCode notebooks)
# 1. Generate the N2 file as an .HTML file
oad.write_n2(CONFIGURATION_FILE, N2_FILE, overwrite=True)
# 2. Read the generated HTML into a string
with open(N2_FILE, 'r', encoding='utf-8') as f:
    html_content = f.read()
escaped_html = html.escape(html_content)  # Escape the HTML so it can be safely embedded

# 3. Display using an IFrame with 'srcdoc' instead of 'src'
iframe_code = f"""
<iframe width="100%" height="600px" style="border: none;" srcdoc="{escaped_html}"></iframe>
"""
display(HTML(iframe_code))


# Display the N2 file in an IFrame (works in Jupyter notebooks)
# from IPython.display import IFrame
# display(IFrame(src=N2_FILE, width="100%", height="500px"))

# Display the N2 file in a new browser tab
# webbrowser.open_new_tab(N2_FILE)
# Out:
# <iframe width="100%" height="600px" style="border: none;" srcdoc="&lt;!doctype html&gt;
# &lt;html&gt;
# &lt;head&gt;
# &lt;title&gt;OpenMDAO Model Hierarchy and N2 diagram&lt;/title&gt;
#
# &lt;meta http-equiv=&quot;Content-Type&quot; content=&quot;text/html; charset=UTF-8&quot;&gt;
# &lt;script type=&quot;text/javascript&quot;&gt;
# window.addEventListener(&quot;error&quot;, handleError, true);
# function handleError(evt) {
#
#     // Cannot define this color in Style since hasn&#x27;t been loaded yet
#     // Cannot call anything in any of the diagram JavaScript code because nothing has been loaded
#     document.body.style.background = &#x27;#db9f9f&#x27;;
#     document.getElementById(&quot;show-error-button-container&quot;).style.visibility = &#x27;visible&#x27;;
#
#     document.getElementById(&#x27;show-error-button&#x27;).onclick = function() {
#        if (evt.error) { // Chrome sometimes provides this
#          alert(&quot;An error has occured while displaying the diagram. This error should be reported as an &quot; +
#                &quot;issue to the OpenMDAO developers.\n\n&quot; +
#                &quot;Error: &quot; + evt.message + &quot;\n\n&quot; +
#                &quot;Stack trace: \n&quot; + evt.error.stack + &quot;\n&quot; );
#        } else {
#          alert(&quot;An error has occured while displaying the diagram. This error should be reported as an issue &quot; +
#                &quot;to the OpenMDAO developers. \n\n&quot; +
#                &quot;For more details about the error, please look in the browser&#x27;s Console using the menu item:\n\n&quot; +
#                &quot;    Develop -&gt; Show JavaScript Console&quot;);
#        }
#     }
# }
#
# &lt;/script&gt;
#
# &lt;style type=&quot;text/css&quot;&gt;
# #n2-windows {
#     position: absolute;
#     width: 100vw;
#     height: 100vw;
# }
#
# #n2-windows div {
#     position: absolute;
# }
#
# .n2-windows-modal-bg {
#     width: 100vw;
#     height: 100vw;
#     opacity: 0.6;
#     background-color: black;
# }
#
# .main-window {
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
# }
#
# .window-contents {
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
# }
#
# /* Use &quot;visibility:hidden&quot; instead of &quot;display: none&quot; here
#    because &quot;display: none&quot; will caused certain operations
#    and calculations on the window to fail. */
# .window-inactive {
#     visibility: hidden;
# }
#
# /* For when the window or window component will not be used
#    or manipulated at all. */
# .window-unused {
#     display: none;
# }
#
# .window-draggable-ribbon {
#     cursor: grab;
# }
#
# /* vvvvvvvvvv Begin N2 Window resizing styles vvvvvvvvvv */
# :root {
#     --resize-overflow: -2px;
#     --resize-edge-size: 5px;
#     --resize-corner-size: 10px;
# }
#
# .resize {
#     top: var(--resize-overflow);
#     left: var(--resize-overflow);
#     right: var(--resize-overflow);
#     bottom: var(--resize-overflow);
#     display: block;
#     opacity: 0;
#     pointer-events: none;
#     background-color:none;
# }
#
# .resize&gt;div {
#     pointer-events: auto;
# }
#
# .rsz-horizontal {
#     height: var(--resize-edge-size);
#     left: var(--resize-corner-size);
#     right: var(--resize-corner-size);
# }
# .rsz-horizontal:hover { cursor: ns-resize; }
#
# .rsz-top { top: 0; }
# .rsz-bottom { bottom: 0; }
#
# .rsz-vertical {
#     width: var(--resize-edge-size);
#     top: var(--resize-corner-size);
#     bottom: var(--resize-corner-size);
# }
# .rsz-vertical:hover { cursor: ew-resize; }
#
# .rsz-right { right: 0; }
# .rsz-left { left: 0; }
#
# .rsz-corner {
#     height: var(--resize-corner-size);
#     width: var(--resize-corner-size);
# }
#
# .rsz-top-right { top: 0; right: 0; cursor: nesw-resize; }
# .rsz-bottom-right { bottom: 0; right: 0; cursor: nwse-resize; }
# .rsz-bottom-left { bottom: 0; left: 0; cursor: nesw-resize; }
# .rsz-top-left { top: 0; left: 0; cursor: nwse-resize; }
#
# /* ^^^^^^^^^^ End N2 Window resizing styles ^^^^^^^^^^ */
#
#
# /* vvvvvvvvvv Begin Default N2 Window theme vvvvvvvvvv */
# .window-theme-default {
#     --header-height: 30px;
#     --ribbon-color: #42926b;
#
#     background-color: white;
#     border: 1px solid #a0a0a0;
#     transition: opacity 0.25s;
#     box-shadow: 3px 3px 3px 1px rgba(0, 0, 0, 0.2);
#
#     border-radius: 10px;
#     overflow: hidden;
# }
#
# .window-theme-default .window-header {
#     background-color: var(--ribbon-color);
#     margin: 0;
#     font-size: 11pt;
#     text-align: right;
#     white-space: nowrap;
#     height: var(--header-height);
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: auto;
# }
#
# .window-theme-default .window-close-button::before {
#     content: &#x27;\2715&#x27;
# }
#
# .window-theme-default .window-close-button {
#     color: none;
#     opacity: 0.4;
#     text-shadow: -0.5px -0.5px 0.5px black, 0.5px 0.5px 0.5px white;
#     position: absolute;
#     top: 0px;
#     right: 8px;
#     cursor: pointer;
#     margin: 0;
#     font-size: 12pt;
#     font-weight: bold;
#     line-height: var(--header-height);
#     padding: 0;
# }
#
# .window-theme-default .window-close-button:hover,
# .window-theme-default .window-close-button:focus {
#     color: #333;
#     text-decoration: none;
#     cursor: pointer;
# }
#
# .window-theme-default .window-header .window-title {
#     color: white;
#     display: block;
#     font-weight: bold;
#     line-height: var(--header-height);
#     position: relative;
#
#     /* Stuff to prevent title bar from being too long */
#     text-overflow: ellipsis;
#     overflow: hidden;
#     width: auto;
#     direction: rtl;
#     text-align: center;
#     margin-left: 15px;
#     margin-right: 25px;
# }
#
# .window-theme-default .window-body {
#     color: black;
#     border: 0;
#     margin: 0;
#     padding: 0;
#
#     top: var(--header-height);
#     left: 0;
#     right: 0;
#     bottom: var(--footer-height);
# }
#
# .window-theme-default .window-footer {
#     display: none;
# }
#
# /* ^^^^^^^^^^ End Default N2 Window theme ^^^^^^^^^^ */
#
# /* vvvvvvvvvv Begin Node Info N2 Window theme vvvvvvvvvv */
# .window-theme-node-info {
#     --header-height: 26px;
#     --footer-height: 15px;
#     --ribbon-color: #42926b;
#
#     background-color: white;
#     border: 1px solid #a0a0a0;
#     transition: opacity 0.25s;
#     box-shadow: 3px 3px 3px 1px rgba(0, 0, 0, 0.2);
#     border-radius: 10px;
#     overflow: hidden;
# }
#
# .window-theme-node-info .window-header {
#     background-color: var(--ribbon-color);
#     margin: 0;
#     font-size: 11pt;
#     text-align: right;
#     white-space: nowrap;
#     height: var(--header-height);
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: auto;
# }
#
# .window-theme-node-info .window-close-button::before {
#     content: &#x27;\2715&#x27;
# }
#
# .window-theme-node-info .window-close-button {
#     color: none;
#     opacity: 0.4;
#     text-shadow: -0.5px -0.5px 0.5px black, 0.5px 0.5px 0.5px white;
#     position: absolute;
#     top: 0px;
#     right: 8px;
#     cursor: pointer;
#     margin: 0;
#     font-size: 12pt;
#     font-weight: bold;
#     line-height: var(--header-height);
#     padding: 0;
# }
#
# .window-theme-node-info .window-close-button:hover,
# .window-theme-node-info .window-close-button:focus {
#     color: #333;
#     text-decoration: none;
#     cursor: pointer;
# }
#
# .window-theme-node-info .window-header .window-title {
#     color: white;
#     display: block;
#     font-weight: bold;
#     line-height: var(--header-height);
#     position: relative;
#
#     /* Stuff to prevent title bar from being too long */
#     text-overflow: ellipsis;
#     overflow: hidden;
#     width: auto;
#     direction: rtl;
#     text-align: center;
#     margin-left: 15px;
#     margin-right: 25px;
# }
#
# .window-theme-node-info .window-body {
#     color: black;
#     border: 0;
#     margin: 0;
#     padding: 0;
#
#     top: var(--header-height);
#     left: 0;
#     right: 0;
#     bottom: var(--footer-height);
# }
#
# .window-theme-node-info .window-footer {
#     background-color: var(--ribbon-color);
#     color: white;
#
#     height: var(--footer-height);
#     top: auto;
#     bottom: 0;
#     left: 0;
#     right: 0;
# }
#
# .window-theme-node-info table {
# 	overflow: hidden;
# 	background-color: white;
#     min-width: 200px;
#     border-collapse: separate;
#     border-spacing: 0;
#     /* width: fit-content; */
#     width: 100%;
#     height: fit-content;
# }
#
# .window-theme-node-info table tbody th {
#     tex

# %% [markdown]
# Also another useful tool is to visualize the XDSM diagram

# %%
# XDSM_FILE = pth.join(WORK_FOLDER_PATH, "xdsm.html")
# oad.write_xdsm(CONFIGURATION_FILE, XDSM_FILE, overwrite=True)

# # 2. Read the generated HTML into a string
# with open(XDSM_FILE, 'r', encoding='utf-8') as f:
#     html_content = f.read()
# escaped_html = html.escape(html_content)  # Escape the HTML so it can be safely embedded

# # 3. Display using an IFrame with 'srcdoc' instead of 'src'
# iframe_code = f"""
# <iframe width="100%" height="600px" style="border: none;" srcdoc="{escaped_html}"></iframe>
# """
# display(HTML(iframe_code))

# # IFrame(src=XDSM_FILE, width="100%", height="500px")

# %% [markdown]
# Once again, we generate a temporary input file for this notebook, so that the reference source file cannot be corrupted:

# %%
oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE, overwrite=True)
# Out:
# 'C:/Users/STEALTH/Documents/VSCodeProjects/FORKS/Modifications/FAST-UAV_FMUC/src/fastuav/notebooks1/workdir/problem_inputs_FMUC.xml'

# %% [markdown]
# The [problem_inputs.xml](./workdir/problem_inputs.xml) file now includes parameters such as the material properties for the spars and the ribs of the wing. Take your time to check these parameters specific to fixed-wing UAVs.

# %%
INPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_inputs_FMUC.xml")
oad.variable_viewer(INPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# ## 2. Running an MDO
#
# You can now run an optimization problem. Here again, some design variables and constraints defined in the [configuration file](./data/configurations/fixedwing_mdo.yaml) are specific to fixed-wing UAVs. For example:
#
# ```yaml
# optimization:
#   design_variables:
#     - name: optimization:variables:geometry:wing:loading:k  # under estimation coefficient on the wing loading
#       lower: 0.1
#       upper: 1.0
#     - name: optimization:variables:geometry:wing:AR  # aspect ratio of the wing
#       lower: 8.0
#       upper: 20.0
#   constraints:
#     - name: optimization:constraints:geometry:fuselage:volume  # fuselage volume requirement (to carry the batteries and the payload)
#       lower: 0.0
# ```

# %%
# optim_problem = oad.optimize_problem(CONFIGURATION_FILE, overwrite=True)
from fastuav.utils.optim_iteration_logger import optimize_problem_with_logging, plot_iteration_log

optim_problem, log_df = optimize_problem_with_logging(
    CONFIGURATION_FILE,
    log_path="./workdir/optim_log.csv",
    overwrite=True,
)
# Out:
# [logger] 21 design vars, 22 constraints, 1 objectives
# [logger] XML snapshot enabled — C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml will be overwritten after every iteration
# [logger] Running optimisation, recording to C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\optim_log_cases.sql
# NL: NLBGS 1 ; nan nan
# NL: NLBGSSolver 'NL: NLBGS' on system '': residuals contain 'inf' or 'NaN' after 1 iterations.
# [snapshot] iter 1: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 0 0
# NL: NLBGS Converged
# C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\.venv\lib\site-packages\scipy\optimize\_slsqp_py.py:435: RuntimeWarning:
#
# Values in x were outside bounds during a minimize step, clipping to bounds
# NL: NLBGS 1 ; 290073.739 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\.venv\lib\site-packages\scipy\optimize\_slsqp_py.py:439: RuntimeWarning:
#
# Values in x were outside bounds during a minimize step, clipping to bounds
# NL: NLBGS 1 ; 4248896.87 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 4246806.74 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 143523.876 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 43027.0463 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 14742.2675 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 9935.73198 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1645.56803 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 10: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 1432.90891 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 6498.20449 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 5835.31831 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 592.490696 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8151.84651 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7316.76377 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 751.769649 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8138.79416 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7305.13586 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 724.190216 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 20: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 8108.77444 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7278.27563 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 655.942363 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8015.02418 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7194.31625 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 524.542979 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7792.57216 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 6995.07763 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7000.12768 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 6104.70625 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 30: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 6136.24951 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 4690.51644 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 4717.18341 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2615.20927 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2735.74863 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 654.442779 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2739.945 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1671.01925 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 3431.04787 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2244.91878 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 40: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 2623.26912 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1320.57644 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1891.29643 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 410.201653 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 386.471808 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 574.863507 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 256.292993 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 913.755195 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 496.379103 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1691.34568 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 50: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 767.724543 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2664.34948 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2413.51056 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 459.334597 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 254.713924 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 116.276427 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 106.753789 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 42.9191062 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 133.894701 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 263.797359 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 60: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 123.716672 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 490.267752 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1585.68644 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 695.415642 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2372.96015 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 10952.1737 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2721.15753 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 443.872411 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 904.686792 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 3429.96818 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 70: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 7984.46566 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8384.39508 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2651.96014 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1313.38768 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2271.1341 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1713.29171 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 400.315152 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 107.613876 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 33.9567521 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 10.8479494 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 80: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 3.47918292 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1.11725975 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.358927502 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.115322952 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.0370546652 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 3342.15464 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2648.17412 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 530.66523 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 119.590567 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 31.9756633 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 90: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 8.63187029 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2.33619527 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.632680948 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.171208019 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.0458027739 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 4375.59254 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 3519.46401 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 668.069064 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 142.251913 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 34.3317835 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 100: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 8.70921615 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 2.21416342 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.56308123 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.142983267 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.0342046986 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 0.00596398665 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 412.206158 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 281.205255 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1081.4939 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1988.4568 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 110: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 1679.87457 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 7208.50792 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 6263.71043 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 3527.43021 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1694.22246 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1457.20399 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1161.91349 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 1691.37497 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 3013.16613 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8345.87518 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# [snapshot] iter 120: wrote C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# NL: NLBGS 1 ; 3118.87612 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 551.626579 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 230.124047 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# NL: NLBGS 1 ; 8.56614049 1
# NL: NLBGS 2 ; 0 0
# NL: NLBGS Converged
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.013341486176432662
#             Iterations: 70
#             Function evaluations: 123
#             Gradient evaluations: 70
# Optimization Complete
# -----------------------------------
# [logger] Driver finished in 362.08s — status: OK
# [logger] Wrote outputs to: C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# [snapshot] 124 XML snapshots written to C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\src\fastuav\notebooks1\workdir\problem_outputs_FMUC.xml
# [logger] 124 cases recorded
# [logger] Wrote 124 rows x 42 cols -> ./workdir/optim_log.csv

# %%
# fig = plot_iteration_log("./workdir/optim_log.csv")
# fig.show()
from fastuav.utils.sql_to_csv import sql_to_csv

df = sql_to_csv(
    "./workdir/optim_log_cases.sql",
    "./workdir/optim_log.csv",
    configuration_file="./data/configurations/fixedwing_mdo_NonPropu_Thin.yaml",
)
df.tail()

from fastuav.utils.optim_iteration_logger import (
    optimize_problem_with_logging,
    plot_iteration_log_interactive,
)

# ... run optimization as before ...

# Interactive version (returns a plotly figure):
fig = plot_iteration_log_interactive("./workdir/optim_log.csv")
fig.show()
# Out:
# [sql->csv] 124 cases in ./workdir/optim_log_cases.sql
# [sql->csv] YAML: 21 DVs, 22 constraints, 1 obj
# [sql->csv] Wrote 124 rows x 42 cols -> ./workdir/optim_log.csv

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs_FMUC.xml")
FW_OUTPUT_FILE = pth.join(SOURCE_FOLDER_PATH, 'problem_outputs_FW_mdo.xml')
shutil.copy(OUTPUT_FILE, FW_OUTPUT_FILE)
# Out:
# './data\\source_files\\problem_outputs_FW_mdo.xml'

# %% [markdown]
# Let's save and visualize these results:

# %%
oad.optimization_viewer(CONFIGURATION_FILE)
# Out:
# C:\Users\STEALTH\Documents\VSCodeProjects\FORKS\Modifications\FAST-UAV_FMUC\.venv\lib\site-packages\jupyter_client\session.py:718: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %%
oad.variable_viewer(OUTPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# ## 3. Analysis and plots
#
# You can now use postprocessing plots to visualize the results of the MDO.

# %%
fig = fixedwing_geometry_plot(OUTPUT_FILE,name="Raymer CDi geometry")
fig = fixedwing_geometry_plot(pth.join(WORK_FOLDER_PATH, "problem_outputs.xml"), name="VLM CDi + Smaller density geometry ",fig=fig)
fig.show()
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Raymer CDi geometry',
#               'type': 'scatter',
#               'uid': 'fc51e991-6a2c-4f60-99f0-45573fe14321',
#               'x': {'bdata': ('AAAAAAAAAIAV4vcxZzXPvxXi9zFnNc' ... 'GO2s/uPwAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAAAAV4vcxZzXPP+2vbfRxE/' ... 'NsLzwDQE3tOn9ggQNAKWQQv3XNAEA='),
#                     'dtype': 'f8'}},
#              {'mode': 'lines+markers',
#               'name': 'VLM CDi + Smaller density geometry ',
#               'type': 'scatter',
#               'uid': 'a6fca7f5-4bb4-4648-b5a7-dfbb1ac9c17b',
#               'x': {'bdata': ('AAAAAAAAAIDuwh2A73vFv+7CHYDve8' ... 'yOMbXkPwAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAAADuwh2A73vFP448P5PmWf' ... 'KB6n36P6ozJWDr2vo/T4xsruI49z8='),
#                     'dtype': 'f8'}}],
#     'layout': {'template': '...',
#                'title': {'text': 'Drone Geometry', 'x': 0.5},
#                'xaxis': {'title': {'text': 'y'}},
#                'yaxis': {'scaleanchor': 'x', 'scaleratio': 1, 'title': {'text': 'x'}}}
# })

# %%
fig = mass_breakdown_sun_plot_drone(OUTPUT_FILE)
fig.show()
